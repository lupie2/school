# %% [markdown]
# # Mathe Trainer
#
# Schreiben Sie ein Python-Programm, um einem Schüler zu helfen, Mathematik zu üben.
# Das Programm sollte den Schüler zuerst fragen, wie viele Übungen er machen möchte.
#
# Fangen Sie die Eingabe einer zu hohen Zahl (z.B. >100) oder eines Strings ab. und fordern eine neue Eingabe an.
# Sollte eine Fliesskommazahl eingegeben werden wird deren Integer-Wert benutzt.
#
# Dann soll das Programm zwei Zufallszahlen zwischen 1 und 10 generieren und zufällig einen Operator + oder - oder * auswählen und eine Übung generieren.
#
# Dann liest es die Antwort des Schülers in der Eingabe und teilt mit, ob die Antwort richtig war. Wenn die Antwort falsch war, sollte die richtige Antwort angezeigt werden.
#
# Auch hier die Eingabe auf eine gültige Zahl hin überprüfen und gegebenenfalls eine neue Eingabe anfordern.
#
# ```python
# >>> Wie viele Übungsläufe möchten Sie machen?  2
# >>> 2 * 7 = ?
# 14
# >>> "Ja, das ist richtig!"
# >>> 3 * 10 = ?
# 21
# >>> "Leider falsch. Die korrekte Antwort lautet: 30"
# ```
# **Die Aufgabe mit den bisher bekannten Funktionen aus Python lösen! Ein "try-except"-Konstrukt soll nicht verwendet werden!!**
# Verwenden Sie stattdessen z.B. die Stringmethoden isnumeric, isdigit .... .
# **(30 Punkte)**

# %%
# Hier Ihren Programmcode eintragen
# Hinweise:eval(), while, isnumeric(), isdigit(), random: randint, choice
from random import randint
from random import choice
operators = ('+', '-', '*')

def ablauf(op):
     zahl1 = randint(1, 10)
     zahl2 = randint(1, 10)
     print(str(zahl1) + str(op) + str(zahl2) + ' = ?')
     eingabe = input('Wie lautet das Ergebnis')
     if eingabe.isdigit():
         match str(op):
             case '+':
                 if int(eingabe) == (zahl1 + zahl2):
                    print('richtig')
                 else:
                    print('falsch')
             case '-':
                 if int(eingabe) == (zahl1 - zahl2):
                    print('richtig')
                 else:
                    print('falsch')
             case '*':
                 if int(eingabe) == (zahl1 * zahl2):
                    print('richtig')
                 else:
                    print('falsch')
     else:
         print('Ergebnis muss eine ganze Zahl sein')

def uebung():
    i = 0
    anzahl = input('Wie viele Übungen willst du machen')
    if anzahl.isdigit():
        while i < int(anzahl):
            op = choice(operators)
            ablauf(op)
            i += 1
    else:
        print('Eingabe muss eine ganze Zahl sein')
uebung()
# Out:
# Wie viele Übungen willst du machen 4
# 10*1 = ?
# Wie lautet das Ergebnis 10
# richtig
# 5+10 = ?
# Wie lautet das Ergebnis 15
# richtig
# 7+10 = ?
# Wie lautet das Ergebnis 13
# falsch
# 5*6 = ?
# Wie lautet das Ergebnis 30
# richtig

# %% [markdown]
# ### Optional
#
# Erweitern Sie Ihre Lösung so, dass neben arithmetischen Operatoren auch boolesche Operatoren unterstützt werden. Der Benutzer sollte nur mit „Wahr“ oder „Falsch“ antworten, ansonsten muss die Eingabe wiederholt werden. ( w und f als Auswahl ist auch OK)
#
# **(5 Punkte zusätzlich)**

# %%
# Hier Ihren Programmcode eintragen
# Hinweise:eval(), while, bin(), random: randint, choice

from random import randint
from random import choice
operators = ('+', '-', '*', '<', '>', '=')

def math(op):
     zahl1 = randint(1, 10)
     zahl2 = randint(1, 10)
     print(str(zahl1) + str(op) + str(zahl2) + ' = ?')
     eingabe = input('Wie lautet das Ergebnis')
     if eingabe.isdigit():
         match str(op):
             case '+':
                 if int(eingabe) == (zahl1 + zahl2):
                    print('richtig')
                 else:
                    print('falsch')
             case '-':
                 if int(eingabe) == (zahl1 - zahl2):
                    print('richtig')
                 else:
                    print('falsch')
             case '*':
                 if int(eingabe) == (zahl1 * zahl2):
                    print('richtig')
                 else:
                    print('falsch')
     else:
         print('Ergebnis muss eine ganze Zahl sein')

def bool(op):
     zahl1 = randint(1, 10)
     zahl2 = randint(1, 10)
     match str(op):
         case '<':
             print('Ist ' + str(zahl1) + str(op) + str(zahl2) + '?')
             eingabe = input('Wie lautet das Ergebnis?')
             match eingabe.lower():
                 case 'w' | 'wahr':
                     if zahl1 < zahl2:
                         print('richtig')
                     else:
                         print('falsch')
                 case 'f' | 'falsch':
                     if zahl1 < zahl2:
                         print('falsch')
                     else:
                         print('richtig')
                 case _:
                     print('Falsche Eingabe. Gib w/wahr oder f/falsch ein als Antwort')
         case '>':
             print('Ist ' + str(zahl1) + str(op) + str(zahl2) + '?')
             eingabe = input('Wie lautet das Ergebnis?')
             match eingabe.lower():
                 case 'w' | 'wahr':
                     if zahl1 > zahl2:
                         print('richtig')
                     else:
                         print('falsch')
                 case 'f' | 'falsch':
                     if zahl1 > zahl2:
                         print('falsch')
                     else:
                         print('richtig')
                 case _:
                     print('Falsche Eingabe. Gib w/wahr oder f/falsch ein als Antwort')
         case '=':
             print('Ist ' + str(zahl1) + str(op) + str(zahl2) + '?')
             eingabe = input('Wie lautet das Ergebnis?')
             match eingabe.lower():
                 case 'w' | 'wahr':
                     if zahl1 == zahl2:
                         print('richtig')
                     else:
                         print('falsch')
                 case 'f' | 'falsch':
                     if zahl1 == zahl2:
                         print('falsch')
                     else:
                         print('richtig')
                 case _:
                     print('Falsche Eingabe. Gib w/wahr oder f/falsch ein als Antwort')

def uebung():
    i = 0
    anzahl = input('Wie viele Übungen willst du machen')
    if anzahl.isdigit():
        while i < int(anzahl):
            op = choice(operators)
            match str(op):
                case '+' | '-' | '*':
                    math(op)
                case '<' | '>' | '=':
                    bool(op)
            i += 1
    else:
        print('Eingabe muss eine ganze Zahl sein')
uebung()
# Out:
# Wie viele Übungen willst du machen 3
# Ist 6<10?
# Wie lautet das Ergebnis? u
# Falsche Eingabe. Gib w/wahr oder f/falsch ein als Antwort
# 2*8 = ?
# KeyboardInterrupt

# %% [markdown]
# ### Optional zum kniffeln
#
# Erweitern Sie Ihre Lösung so, dass bitweise Operatoren unterstützt werden.
# Die Eingabe und Ausgabe sollte die binäre Form (010011) unterstützen.Der Binärwert sollte maximal 8 Stellen lang sein. Bei Fehler muss die Eingabe wiederholt werden oder mit 'quit' abgebrochen werden.
#
# **(15 Punkte zusätzlich)**

# %%
# Hier Ihren Programmcode eintragen
# Hinweise:eval(), while, bin(), random: randint, choice
