# %%
import tkinter as tk
from tkinter import messagebox
window = tk.Tk()
window.title('my first tk program')
window.geometry('400x400')
# Out:
# ''

# %%
tk.Label(window, text='Enter').pack()
tk.Text(window, width=40, height = 6).pack()
#entry = tk.Entry(window)
#entry.pack()
zahl1 = tk.Entry(window)
zahl2 = tk.Entry(window)
zahl3 = tk.Entry(window)
zahl1.pack()
zahl2.pack()
zahl3.pack()
def click_method():
    messagebox.showinfo('clicked!', 'you clicked me')
    pass

# %%
def sayHello():
    text = entry.get()
    messagebox.showinfo('hello', f'hello mr/mrs: {text}')

# %%
def rechner():
    x = int(zahl1.get())
    y = int(zahl2.get())
    z = int(zahl3.get())
    messagebox.showinfo('Ergebnis', f'Durchschnitt von {x}, {y} und {z} ist {(x+y+z)/3}')
tk.Button(window, text='click me', command=rechner).pack()

# %%
window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\LukasPietsch\anaconda3\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\LukasPietsch\AppData\Local\Temp\ipykernel_25952\4018525017.py", line 2, in rechner
#     x = int(zahl1.get())
# ValueError: invalid literal for int() with base 10: ''
