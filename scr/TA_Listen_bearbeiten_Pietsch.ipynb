# %% [markdown]
# # Übungen zu Listen
#
# Nutzen Sie diese Liste als Beispiel für die folgenden Aufgaben.
#
# ```python
# mylist = [56, 25, 36, 43, 9, 50, 33, 42, 33, 14, 17, 52, 45, 14, 8, 42, 4, 14, 20]
# ```
#
# Aber die Lösungen sollen auch mit jeder anderen Liste funktionieren!
#
# Bitte eine **eigene Liste** generieren und damit zusätzlich testen. (**mischen Sie int und float**)
# Versuchen Sie auch mehrere Lösungen für die gleiche Aufgabe zu finden.
# Die Lösungen sollen auf Listenmethoden und dem bisher gelernten Unterrichtsstoff basieren und nicht auf Funktionen aus anderen Bereichen und Bibliotheken!
#
# Wenn Sie fertig sind, bitte das Notebook oder die .py Datei(n) hochladen, damit diese bewertet werden können.
#
# Viel Erfolg

# %%
# Beispielliste 
mylist = [56, 25, 36, 43, 9, 50, 33, 42, 33, 14, 17, 52, 45, 14, 8, 42, 4, 14, 20]

# eigene Liste
yourlist = [1, 2, 4.5, 3.14552244, 773, 42, 7.7, 0.1, 666.666, 1234]

# %% [markdown]
# 1. Summieren Sie alle Elemente dieser Liste.

# %%
# Schreiben Sie Ihren Programmcode hier
print(sum(mylist))

#meine Liste
print(sum(yourlist))
# Out:
# 557
# 2734.11152244

# %% [markdown]
# 2. Schreiben Sie ein Python-Programm, um die größte Zahl aus einer Liste zu erhalten.

# %%
# Schreiben Sie Ihren Programmcode hier
mylist.sort()
print(mylist.pop())

# meine Liste
yourlist.sort()
print(yourlist.pop())
# Out:
# 56
# 1234

# %% [markdown]
# 3. Schreiben Sie ein Python-Programm, um die Reihenfolge einer Liste umzukehren.

# %%
# Schreiben Sie Ihren Programmcode hier
# Beispielliste 
mylist = [56, 25, 36, 43, 9, 50, 33, 42, 33, 14, 17, 52, 45, 14, 8, 42, 4, 14, 20]
mylist.sort(reverse = True)
print(mylist)

#meine Liste
yourlist.sort(reverse = True)
print(yourlist)
# Out:
# [56, 52, 50, 45, 43, 42, 42, 36, 33, 33, 25, 20, 17, 14, 14, 14, 9, 8, 4]
# [773, 666.666, 42, 7.7, 4.5, 3.14552244, 2, 1, 0.1]

# %% [markdown]
# 4. Schreiben Sie ein Python-Programm, um zu prüfen, ob eine Liste leer ist oder nicht.

# %%
# Schreiben Sie Ihren Programmcode hier
mylist = [56, 25, 36, 43, 9, 50, 33, 42, 33, 14, 17, 52, 45, 14, 8, 42, 4, 14, 20]
thislist = []
x = 0
for i in mylist:
    x = x + 1
if x > 0:
    print('Liste gefüllt mit ' + str(x) + ' Elementen')
else:
    print('Liste leer')

# leere Liste
x = 0
for i in thislist:
    x = x + 1
if x > 0:
    print('Liste gefüllt mit ' + str(x) + ' Elementen')
else:
    print('Liste leer')

# meine Liste
x = 0
for i in yourlist:
    x = x + 1
if x > 0:
    print('Liste gefüllt mit ' + str(x) + ' Elementen')
else:
    print('Liste leer')
# Out:
# Liste gefüllt mit 19 Elementen
# Liste gefüllt mit 9 Elementen
# Liste leer

# %% [markdown]
# 5. Schreiben Sie ein Programm, welches alle Zahlen der Liste mix_list addiert.
#
# Lösungsansatz:
#
# - for i in mix_list:
# - type() Prüfung

# %%
mix_list = [12, 3.3, -2, 'Flasche', 9, -4.1, 'Weg', 'auto', 2, 77, 0.5, 'X', 'Bla', 66.6, 22]

# %%
# Schreiben Sie Ihren Programmcode hier
x = 0
for i in mix_list:
    if (type(i)) == int or (type(i)) == float:
        x = x + i
print(x)
# Out:
# 186.3

# %% [markdown]
# 6. Vergleichen Sie 2 Listen und passen die 2. Liste entsprechend der Vorgaben an:
#
# - Prüfen Sie ob Elemente der 1. Liste in der 2. Liste vorkommen und geben diese Elemente aus.
# - Prüfen Sie wie oft die gefundenen Element aus Liste 1 in der 2. Liste vorhanden sind und geben diese Elemente aus.
# - Löschen Sie alle mehrfach vorkommende Elemente aus Liste 1 in der 2. Liste bis auf eins und geben Sie diese Liste aus.

# %%
# Listen
liste_1 = ['banana', 'peach', 'orange', 'apple']
liste_2 = ['apple', 'peach', 'lemon', 'banana', 'orange', 'pear', 'banana', 'apple', 'peach',
           'peach', 'banana', 'orange', 'banana']

# %%
# Schreiben Sie Ihren Programmcode hier
for i in liste_1:
    if i in liste_2:
        print(i)
# Out:
# banana
# peach
# orange
# apple

# %%
# Ohne die .count() Methode zu verwenden
zaehler = 0
x = 0
for i in liste_1:
    for j in liste_2:
        if j == i: 
            zaehler = zaehler + 1
    print(i, zaehler)
    zaehler = 0

for i in liste_1:
    while i in liste_2:
        liste_2.remove(i)
    liste_2.append(i)
print(liste_2)
# Out:
# banana 4
# peach 3
# orange 2
# apple 2
# ['lemon', 'pear', 'banana', 'peach', 'orange', 'apple']

# %%
# Löschen Sie alle mehrfach vorkommende Elemente aus Liste 1 in der 2. Liste bis auf eins und geben Sie diese Liste aus. 
# Schreiben Sie Ihren Programmcode hier
liste_1 = ['banana', 'peach', 'orange', 'apple']
liste_2 = ['apple', 'peach', 'lemon', 'banana', 'orange', 'pear', 'banana', 'apple', 'peach',
           'peach', 'banana', 'orange', 'pear', 'banana', 'strawberry', 'lemon']
for i in liste_1:
    while i in liste_2: 
        liste_2.remove(i)
    liste_2.append(i)
print(liste_2)
# Out:
# ['lemon', 'pear', 'pear', 'strawberry', 'lemon', 'banana', 'peach', 'orange', 'apple']

# %%
# Schreiben Sie Ihren Programmcode hier
# Auch doppelte Element(e), die nicht in Liste 1 sind, entfernen!
for i in liste_2:
    while i in liste_2:
        liste_2.remove(i)
    liste_2.append(i)
print(liste_2)
# Out:
# ['strawberry', 'banana', 'orange', 'lemon', 'peach', 'pear', 'apple']
