# %%
'''
working on a program that asks the user for a string and then searches the first 1000000 digits of pi for that string

1. clean pi.txt to delete spaces and new lines
2. input asking user for string
3. search pi
'''
import tkinter as tk

# %%
#the file  containing the first 1000000 digits of pi was formatted using a lot of spaces and \n commands, so I had to clean it up
file = "pi.txt"
with open(file, "r") as f:
    new = f.read()
# remove spaces and \n
new = new.replace(" ", "").replace("\n", "")

#save the modified content
with open(file, "w") as f:
    f.write(new)

# %%
#create window with entry widget, a button and a label

root=tk.Tk()

# setting the windows size
root.geometry("600x400")

# declaring the searchable string variable
string=tk.StringVar()

# convert the string into integers
def convert():
    number = ''
    for i in string.lower():
        if i == 'a':
            number + '1'
        elif i == 'b':
            number + '2'
        elif i == 'c':
            number + '3'
        elif i == 'd':
            number + '4'
        elif i == 'e':
            number + '5'
        elif i == 'f':
            number + '6'
        elif i == 'g':
            number + '7'
        elif i == 'h':
            number + '8'
        elif i == 'i':
            number + '9'
        elif i == 'j':
            number + '10'
        elif i == 'k':
            number + '11'
        elif i == 'l':
            number + '12'
        elif i == 'm':
            number + '13'
        elif i == 'n':
            number + '14'
        elif i == 'o':
            number + '15'
        elif i == 'p':
            number + '16'
        elif i == 'q':
            number + '17'
        elif i == 'r':
            number + '18'
        elif i == 's':
            number + '19'
        elif i == 't':
            number + '20'
        elif i == 'u':
            number + '21'
        elif i == 'v':
            number + '22'
        elif i == 'w':
            number + '23'
        elif i == 'x':
            number + '24'
        elif i == 'y':
            number + '25'
        elif i == 'z':
            number + '26'
        else:
            

# defining the function that searches the string in pi
def search():
    string=string.get()
    print("The name is : " + name)


# creating a label for the string
string_label = tk.Label(root, text = 'Put in the string \nyou want to find')

# creating the entry field for the string
string_entry = tk.Entry(root,textvariable = string)

# creating a button using the widget
search_btn=tk.Button(root,text = 'Search', command = search)

# using grid method to place label, entry and button
string_label.grid(row=0,column=0)
string_entry.grid(row=0,column=1)
search_btn.grid(row=2,column=1)

root.mainloop()
